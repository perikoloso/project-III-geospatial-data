# %%
 # SETUP NEEDED LIBS

import requests
from pymongo import MongoClient
import pandas as pd
import os
import src.transforming as transf
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### 1. Connect to dataset **companies** stored in MongoDB

# %%
#1.1 Connect to Companies dataset in Mongo

client = MongoClient("localhost:27017")
db = client.get_database("IronHack")
companies = db.get_collection("Companies")

# %%
#2 Get context of conditions for Startups > 1000000. Developers company are discarded as I didn't find a match between them.
# Online is a good option to talk or to discuss about development.

filters = {
    "$and": [
        {"total_money_raised": {"$regex": ".*[MB].*"}},
        {"tag_list": {"$regex": ".*start.*"}},        
    ]
}

df_context = transf.filtering_companies(companies,filters)
df_context
df_companies  = df_context.dropna(subset=["lat"]) # Dropping companies without coordinates.

# Resetting the indices using df.reset_index()
df_companies = df_companies.reset_index(drop=True)

df_companies
# Out:
#             name     category_code  number_of_employees  founded_year  \
# 0         Getyoo            mobile                 10.0          2009
# 1     Samasource        enterprise                 25.0          2008
# 2           Echo        enterprise                 50.0          2007
# 3       Seedcamp           finance                  4.0          2007
# 4    Idea Shower  public_relations                  1.0          2007
# 5     Pageflakes               web                 20.0          2006
# 6       Netvibes               web                 35.0          2005
# 7     Moviestorm          software                 10.0          2005
# 8          Kareo          software                250.0          2004
# 9   SecondMarket           finance                140.0          2004
# 10     Stratavia          software                 45.0          2001
#
#                                              tag_list total_money_raised  \
# 0   social-networks, networking, web, real-life, w...             €1.13M
# 1   outsourcing, crowdsourcing, non-profit-outsour...             $1.21M
# 2   platform, real-time, website, digital, social-...              $4.8M
# 3   seedcamp, business, startup, incubator, entrep...                €5M
# 4       ideas, startups, web-development, programming              $2.3M
# 5             homepage, ajaxhomepage, ajax, startpage              $4.1M
# 6   homepage, ajaxhomepage, ajax, startpage, pagef...               $16M
# 7   animation, start-up, consumer-software, cambridge              £4.3M
# 8   vc-firm, startup, cloud-based-solutions, healt...             $51.4M
# 9   private-company-stock, auction-rate-securities...             $34.2M
# 10  software, automation, database-automation, run...             $10.7M
#
#             city1          city2 country        lat         lon
# 0        Brussels           None    None  50.839970    4.346472
# 1   San Francisco           None    None  37.778991 -122.401803
# 2   San francisco           None    None  38.072936 -122.187963
# 3          London           None    None  51.510880   -0.141897
# 4     Minneapolis           None    None  44.977482  -93.264351
# 5   San Francisco           None    None  37.758113 -122.414689
# 6           Paris  San Francisco     USA  48.870806    2.346680
# 7       Cambridge           None    None  52.197471    0.130588
# 8          Irvine           None    None  33.676444 -117.858700
# 9        New York  San Francsico     USA  40.705439  -74.012822
# 10         Denver           None    None  39.746273 -104.991157

# %% [markdown]
# #### Base dataset is alredy done and ready to be explored

# %% [markdown]
# #### **Start actions with Foursquares to find services regarding project conditions**

# %%
# Get all topics from Foursquare to check which of companies that I filtered has best position to accomplish conditions

result = transf.get_topics(df_context,["Elementary School","Airport Terminal","Basketball Court","Starbucks","Coffee Shop","Vegan Restaurant","Bar","pets"])

# %%
result.to_csv("../project-III-geospatial-data/data/from_f4s.csv")

# %% [markdown]
# #### Checkpoint: saving all FSQ results to CSV file to avoid blocking risk.

# %%
result = pd.read_csv("../project-III-geospatial-data/data/from_f4s.csv")

# %%
# Filtering items from FSQ as many of them are in heterogeneous categories. 
# Let's normalize data. I'll create datasets by for every topic and I'll merge them later.
# As output,I'll have a dataframe with all needed venues based on candidates places.

rs_school = result[result["Category"]=='Elementary School']
rs_vegan = result[result['Category'].str.contains("vegan", case=False)]
rs_starbucks = result[result['Name'].str.contains("starbucks", case=False)]
rs_starbucks.loc[:, 'Category'] = "Starbucks"

rs_basket = result[result['Category'].str.contains("basketball", case=False)]
rs_basket.loc[:, 'Category'] = "Basket"

rs_airport = result[result['Category'].str.contains("Airport Terminal", case=False)]
rs_bars  = result[result['Category'].str.contains("bar", case=False)]
rs_bars.loc[:, 'Category'] = "Bar"
rs_pets  = result[result['Category'].str.contains("grooming", case=False)]


df_final = pd.concat([rs_school, rs_vegan, rs_starbucks, rs_basket, rs_airport,rs_bars,rs_pets], ignore_index=True)

# %%
df_final.info()
df_final = df_final.drop(['Unnamed: 0'], axis=1)
df_final
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 926 entries, 0 to 925
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  926 non-null    int64
#  1   Name        926 non-null    object
#  2   Lat         926 non-null    float64
#  3   Long        926 non-null    float64
#  4   Distance    926 non-null    float64
#  5   Category    926 non-null    object
#  6   Company     926 non-null    object
#  7   City        926 non-null    object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 58.0+ KB
#                                                   Name        Lat        Long  \
# 0                  Basisschool St-Jan Berchmanscollege  50.841114    4.345791
# 1                       Vrije Basisschool - Sint-Joris  50.838791    4.342871
# 2                     Ecole d apllication charles buls  50.838187    4.342025
# 3                               Sint-Joris Basisschool  50.844420    4.348585
# 4                                         Bsgo De Bron  50.834831    4.340237
# ..                                                 ...        ...         ...
# 921  Woof in Boots | Doggy Day Care | Boarding | Gr...  39.729080 -104.996898
# 922                                         Urban Dogg  39.746304 -104.978933
# 923                               Kriser's Natural Pet  39.756777 -104.999448
# 924               Peaceful Touch Pet Salon and Massage  39.740222 -104.971794
# 925                                     City Bark Lodo  39.766969 -104.982251
#
#      Distance              Category    Company      City
# 0       143.0     Elementary School     Getyoo  Brussels
# 1       255.0     Elementary School     Getyoo  Brussels
# 2       369.0     Elementary School     Getyoo  Brussels
# 3       505.0     Elementary School     Getyoo  Brussels
# 4       719.0     Elementary School     Getyoo  Brussels
# ..        ...                   ...        ...       ...
# 921    1967.0  Pet Grooming Service  Stratavia    Denver
# 922    1009.0  Pet Grooming Service  Stratavia    Denver
# 923    1346.0  Pet Grooming Service  Stratavia    Denver
# 924    1780.0  Pet Grooming Service  Stratavia    Denver
# 925    2424.0  Pet Grooming Service  Stratavia    Denver
#
# [926 rows x 7 columns]

# %%
# Now., I'll generate a pivot table with dataframe to check which candidate accomplish better expected conditions
pivot_company = pd.crosstab(df_final['Category'], df_final['Company'],margins=False,margins_name="Total")
pivot_company
# Out:
# Company                          Echo  Getyoo  Idea Shower  Kareo  Moviestorm  \
# Category
# Airport Terminal                    0       0            1      6           0
# Bar                                 1      41           26      9          17
# Basket                              0       2            4      0           1
# Elementary School                   6      47           22      6          14
# Pet Grooming Service                0       1            4      0           0
# Starbucks                           9      12           17     18           6
# Vegan and Vegetarian Restaurant     0       5            0      1           4
#
# Company                          Netvibes  Pageflakes  Samasource  \
# Category
# Airport Terminal                        0           0           0
# Bar                                    34          27          17
# Basket                                  2           3           2
# Elementary School                      50          50          50
# Pet Grooming Service                    2           9          10
# Starbucks                              40           9          39
# Vegan and Vegetarian Restaurant         8           0           1
#
# Company                          SecondMarket  Seedcamp  Stratavia
# Category
# Airport Terminal                            0         0          0
# Bar                                        22        23         36
# Basket                                      8         2          0
# Elementary School                          43        32         24
# Pet Grooming Service                        8         1          5
# Starbucks                                  34        29         21
# Vegan and Vegetarian Restaurant             1         4          0

# %%
#After check this pivot table, we can see that Idea Shower company in Minneapolis, USA , it's a good candidate to cover our conditions as expected
df_candidate = df_companies[df_companies["name"]=='Idea Shower']
df_candidate
# Out:
#           name     category_code  number_of_employees  founded_year  \
# 4  Idea Shower  public_relations                  1.0          2007
#
#                                         tag_list total_money_raised  \
# 4  ideas, startups, web-development, programming              $2.3M
#
#          city1 city2 country        lat        lon
# 4  Minneapolis  None    None  44.977482 -93.264351

# %%
# Now, I'll build a new dataframe filtering all venues to get just those that are close to our candidate

df_surround_candidate  = df_final[df_final['Company'] ==  "Idea Shower"]

df_surround_candidate # All venues that are close to this company in a radius of 2500 mts
df_surround_candidate
# Out:
#                                 Name        Lat       Long  Distance  \
# 135        Emerson Elementary School  44.968294 -93.280364    1581.0
# 136       Hennepin Elementary School  44.961302 -93.271211    1902.0
# 137       Minneapolis Public Schools  44.981505 -93.262388     472.0
# 138  Downtown Open Elementary School  44.975665 -93.269897     480.0
# 139   Religion Information Resources  44.972300 -93.260737     642.0
# ..                               ...        ...        ...       ...
# 764                       Aster Cafe  44.984604 -93.255118    1077.0
# 898                    Downtown Dogs  44.978620 -93.290687    2107.0
# 899               City Paws Pet Club  44.980918 -93.262398     394.0
# 900             The Good Pet Groomer  44.962471 -93.277028    1942.0
# 901    Metro Dogs Daycare & Boarding  44.989546 -93.285825    2147.0
#
#                  Category      Company         City
# 135     Elementary School  Idea Shower  Minneapolis
# 136     Elementary School  Idea Shower  Minneapolis
# 137     Elementary School  Idea Shower  Minneapolis
# 138     Elementary School  Idea Shower  Minneapolis
# 139     Elementary School  Idea Shower  Minneapolis
# ..                    ...          ...          ...
# 764                   Bar  Idea Shower  Minneapolis
# 898  Pet Grooming Service  Idea Shower  Minneapolis
# 899  Pet Grooming Service  Idea Shower  Minneapolis
# 900  Pet Grooming Service  Idea Shower  Minneapolis
# 901  Pet Grooming Service  Idea Shower  Minneapolis
#
# [74 rows x 7 columns]

# %% [markdown]
# ## LET'S PLOT

# %%
import folium
from folium import Choropleth, Circle, Marker, Icon, Map, TileLayer
from folium.plugins import HeatMap, MarkerCluster
import geopandas as gpd
import json

# %%
transf.create_geojson(df_surround_candidate, '../project-III-geospatial-data/data/all_items_pivot.geojson')

# %%
geo_json = "../project-III-geospatial-data/data/all_items_pivot.geojson"
df = pd.read_json(geo_json)
df
# Out:
#                  type                                           features
# 0   FeatureCollection  {'type': 'Feature', 'properties': {'Name': 'Em...
# 1   FeatureCollection  {'type': 'Feature', 'properties': {'Name': 'He...
# 2   FeatureCollection  {'type': 'Feature', 'properties': {'Name': 'Mi...
# 3   FeatureCollection  {'type': 'Feature', 'properties': {'Name': 'Do...
# 4   FeatureCollection  {'type': 'Feature', 'properties': {'Name': 'Re...
# ..                ...                                                ...
# 69  FeatureCollection  {'type': 'Feature', 'properties': {'Name': 'As...
# 70  FeatureCollection  {'type': 'Feature', 'properties': {'Name': 'Do...
# 71  FeatureCollection  {'type': 'Feature', 'properties': {'Name': 'Ci...
# 72  FeatureCollection  {'type': 'Feature', 'properties': {'Name': 'Th...
# 73  FeatureCollection  {'type': 'Feature', 'properties': {'Name': 'Me...
#
# [74 rows x 2 columns]

# %%
rs_starbucks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 234 entries, 769 to 2293
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  234 non-null    int64
#  1   Name        234 non-null    object
#  2   Lat         234 non-null    float64
#  3   Long        234 non-null    float64
#  4   Distance    234 non-null    float64
#  5   Category    234 non-null    object
#  6   Company     234 non-null    object
#  7   City        234 non-null    object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 16.5+ KB

# %% [markdown]
# #### MAP SURROUNDING TARGET

# %%
v_lat = df_final.Lat.mean()
v_lon =df_final.Long.mean()
map_all = Map(location = [v_lat, v_lon], zoom_start=2.)


for index, row in df_companies.iterrows():
    folium.Circle(
    [row["lat"], row["lon"]],
    radius=2000, 
    popup='Range distance', 
    color="#e74c3c",       # rouge
    fill_color="#27ae60",  # vert
    fill_opacity=0.2
    ).add_to(map_all)
    

# Adding datasets by category

for index, row in df_final.iterrows():

    bubble = folium.CircleMarker(
    [row['Lat'], row['Long']],
    radius=10, 
    popup='Candidates location', 
    color="#e74c3c",       # 
    fill_color="#cc99ff",  # 
    fill_opacity=0.7


    #folium.Marker(
    #    location=[row['Lat'], row['Long']],
    #    popup=row['Name'],
    #    icon=folium.Icon(color='orange', icon='')

    ).add_to(map_all)
    
folium.TileLayer('cartodbpositron').add_to(map_all)

map_all
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef3d73a6bce8b4400192a1111c2d0749 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef3d73a6bce8b4400192a1111c2d0749&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef3d73a6bce8b4400192a1111c2d0749 = L.map(
#                 &quot;map_ef3d73a6bce8b4400192a1111c2d0749&quot;,
#                 {
#                     center: [43.88641257042847, -61.51864669216978],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2.0,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43354d2c090acfb9d068a10d5a542add = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ef3d73a6bce8b4400192a1111c2d0749);
#
#
#             var circle_ab96b4f643c956f2ce18c51f320d22ed = L.circle(
#                 [50.83997, 4.3464721],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e74c3c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#27ae60&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ef3d73a6bce8b4400192a1111c2d0749);
#
#
#         var popup_a8766b8d6aac8cbb2a88aec5a4e25e7a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_36c35ba60dc985a363d62353ddd52f8b = $(`&lt;div id=&quot;html_36c35ba60dc985a363d62353ddd52f8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Range distance&lt;/div&gt;`)[0];
#                 popup_a8766b8d6aac8cbb2a88aec5a4e25e7a.setContent(html_36c35ba60dc985a363d62353ddd52f8b);
#
#
#
#         circle_ab96b4f643c956f2ce18c51f320d22ed.bindPopup(popup_a8766b8d6aac8cbb2a88aec5a4e25e7a)
#         ;
#
#
#
#
#             var circle_8ba1465b2b6213103a57cba4e35a1107 = L.circle(
#                 [37.778991, -122.401803],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e74c3c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#27ae60&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ef3d73a6bce8b4400192a1111c2d0749);
#
#
#         var popup_58cac68f0dadc35ccd29fce9e67beef9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8ad24eabdc95735a13689b0e9108b774 = $(`&lt;div id=&quot;html_8ad24eabdc95735a13689b0e9108b774&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Range distance&lt;/div&gt;`)[0];
#                 popup_58cac68f0dadc35ccd29fce9e67beef9.setContent(html_8ad24eabdc95735a13689b0e9108b774);
#
#
#
#         circle_8ba1465b2b6213103a57cba4e35a1107.bindPopup(popup_58cac68f0dadc35ccd29fce9e67beef9)
#         ;
#
#
#
#
#             var circle_8b2cfc84ef0955e69f729a7e91ee94de = L.circle(
#                 [38.0729365, -122.1879633],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e74c3c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#27ae60&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ef3d73a6bce8b4400192a1111c2d0749);
#
#
#         var popup_a49c2ea00d7c30cccde2c78dabd4c899 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d26e98db90127a9300044573f282f43a = $(`&lt;div id=&quot;html_d26e98db90127a9300044573f282f43a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Range distance&lt;/div&gt;`)[0];
#                 popup_a49c2ea00d7c30cccde2c78dabd4c899.setContent(html_d26e98db90127a9300044573f282f43a);
#
#
#
#         circle_8b2cfc84ef0955e69f729a7e91ee94de.bindPopup(popup_a49c2ea00d7c30cccde2c78dabd4c899)
#         ;
#
#
#
#
#             var circle_e5f417e904164f848927269dc19503b3 = L.circle(
#                 [51.5108803, -0.1418973],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e74c3c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&

# %%
v_lat = df_candidate.lat.values[0]
v_lon =df_candidate.lon.values[0]
map_start = Map(location = [v_lat, v_lon], zoom_start=15)
candidate = Marker(location = [v_lat, v_lon], tooltip="IDEA SHOWER - New office!")
circle = folium.Circle(
    [v_lat, v_lon],
    radius=2500, 
    popup='Range distance', 
    color="#e74c3c",       # 
    fill_color="#cc99ff",  # 
    fill_opacity=0.2
)
circle_center = folium.Circle(
    [v_lat, v_lon],
    radius=500, 
    popup='Range distance', 
    color="#ffffff",       # 
    fill_color="#ffff99",  # 
    fill_opacity=0.5
)
circle.add_to(map_start)
circle_center.add_to(map_start)
candidate.add_to(map_start)

# Adding datasets by category



for index, row in rs_basket.iterrows():
    folium.Marker(
        location=[row['Lat'], row['Long']],
        popup=row['Name'],
        icon=folium.Icon(color='orange', prefix="fa", icon='futbol')

    ).add_to(map_start)

for index, row in rs_pets.iterrows():
    folium.Marker(
        location=[row['Lat'], row['Long']],
        popup=row['Name'],
        icon=folium.Icon(color='pink', prefix="fa", icon='scissors ')

    ).add_to(map_start)

for index, row in rs_bars.iterrows():
    folium.Marker(
        location=[row['Lat'], row['Long']],
        popup=row['Name'],
        icon=folium.Icon(color='black', prefix="fa", icon='beer')
    ).add_to(map_start)

for index, row in rs_school.iterrows():
    folium.Marker(
        location=[row['Lat'], row['Long']],
        popup=row['Name'],
        icon=folium.Icon(color='red', prefix="fa", icon='graduation-cap')
    ).add_to(map_start)

for index, row in rs_starbucks.iterrows():
    folium.Marker(
        location=[row['Lat'], row['Long']],
        popup=row['Name'],
        icon=folium.Icon(color='green', icon='star')
    ).add_to(map_start)

for index, row in rs_vegan.iterrows():
    folium.Marker(
        location=[row['Lat'], row['Long']],
        popup=row['Name'],
        icon=folium.Icon(color='red', prefix='fa', icon='pied-piper')
    ).add_to(map_start)

folium.Marker(
        location=[44.886401125849154, -93.21280029988941],
        popup="Aeropuerto Internacional de Mineápolis-Saint Paul",
        icon=folium.Icon(color='purple', prefix='fa', icon='plane')
    ).add_to(map_start)

folium.PolyLine([(44.968294, -93.280364),(44.886401125849154, -93.21280029988941)]).add_to(map_start)
folium.TileLayer('Stamen Watercolor').add_to(map_start)

map_start
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5189be154ec5e8ea1b77e3fb3bfb637d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5189be154ec5e8ea1b77e3fb3bfb637d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5189be154ec5e8ea1b77e3fb3bfb637d = L.map(
#                 &quot;map_5189be154ec5e8ea1b77e3fb3bfb637d&quot;,
#                 {
#                     center: [44.977482, -93.264351],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b3d8e4bf4d62f4675486f5e21418119 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5189be154ec5e8ea1b77e3fb3bfb637d);
#
#
#             var circle_49041b036bdff2ae25deb3b29c04e3f2 = L.circle(
#                 [44.977482, -93.264351],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e74c3c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#cc99ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2500, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5189be154ec5e8ea1b77e3fb3bfb637d);
#
#
#         var popup_a485b35fd0e1c9304fcfe7ff2dc666f5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ae37926398aa53a9e225e92a0232698b = $(`&lt;div id=&quot;html_ae37926398aa53a9e225e92a0232698b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Range distance&lt;/div&gt;`)[0];
#                 popup_a485b35fd0e1c9304fcfe7ff2dc666f5.setContent(html_ae37926398aa53a9e225e92a0232698b);
#
#
#
#         circle_49041b036bdff2ae25deb3b29c04e3f2.bindPopup(popup_a485b35fd0e1c9304fcfe7ff2dc666f5)
#         ;
#
#
#
#
#             var circle_1ec58ee6874fc5096e755fe96aa17c74 = L.circle(
#                 [44.977482, -93.264351],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffffff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffff99&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 500, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5189be154ec5e8ea1b77e3fb3bfb637d);
#
#
#         var popup_3fe3d177da8198b9e72b678fce42980c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f9b24304f3a118431bac657c74161843 = $(`&lt;div id=&quot;html_f9b24304f3a118431bac657c74161843&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Range distance&lt;/div&gt;`)[0];
#                 popup_3fe3d177da8198b9e72b678fce42980c.setContent(html_f9b24304f3a118431bac657c74161843);
#
#
#
#         circle_1ec58ee6874fc5096e755fe96aa17c74.bindPopup(popup_3fe3d177da8198b9e72b678fce42980c)
#         ;
#
#
#
#
#             var marker_434717f609e6d0f5cf7c2ecaf0d12860 = L.marker(
#                 [44.977482, -93.264351],
#                 {}
#             ).addTo(map_5189be154ec5e8ea1b77e3fb3bfb637d);
#
#
#             marker_434717f609e6d0f5cf7c2ecaf0d12860.bindTooltip(
#                 `&lt;div&gt;
#                      IDEA SHOWER - New office!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6e7f5e47d4ed68c42f1176ee9c6703a7 = L.marker(
#                 [50.853073, 4.341971],
#                 {}
#             ).addTo(map_5189be154ec5e8ea1b77e3fb3bfb637d);
#
#
#             var icon_7257a5aa3568e2cd8842499cc9009644 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;futbol&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6e7f5e47d4ed68c42f1176ee9c6703a7.setIcon(icon_7257a5aa3568e2cd8842499cc9009644);
#
#
#         var popup_46144b6d02da1f4bf32d9ad81655bd5d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4d3e9550599f9695e5f8f563d5f612e4 = $(`&lt;div id=&quot;html_4d3e9550599f9695e5f8f563d5f612e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Basketball Court Graanmarkt&lt;/div&gt;`)[0];
#                 popup_46144b6d02da1f4bf32d9ad81655bd5d.setContent(html_4d3e9550599f9695e5f8f563d5f612e4);
#
#
#
#         marker_6e7
